# %%
""""

Requirements : MXNET

"""
# Out:
# '"\n\nRequirements : MXNET\n\n'

# %%
# !pip install mxnet

# %%
path_to_Engagement_Model='/content/drive/MyDrive/Projects/IBY/Engagement_Model/'    ######## Change this path to Engagement Model's path #########

# %%
cd $path_to_Engagement_Model
# Out:
# /content/drive/MyDrive/Projects/IBY/Engagement_Model

# %%
import sys
sys.path.append(path_to_Engagement_Model)

# %%
from main_code import *

# %%
def Driver_function(video_path,max_eye_offset=25):
  """
    Takes video_path as input and outputs Label 
    for each frame along with time frame for each frame.

    labels_and_timestamps is a list of length = Number of frames in the video
    Each element of List is also a list of three elements.
    The first element is a string named - Engaged or DisEngaged.
    Second element is an integer indicating start time of that frame.
    Third element is also an integer indicating end time of that frame.
  """
  labels_and_timestamps=main(video_path,max_eye_offset)

  return labels_and_timestamps

# %%
labels_and_timestamps=Driver_function("Input1.mp4")
